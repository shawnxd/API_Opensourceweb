# %%
from selenium import webdriver
from urllib import parse
import bs4
import re
import time
import pandas as pd
def load_data(State):
    dblocation = '/Users/graceli/Desktop/SBR automation/Company Database.db'
    import pandas as pd
    import sqlite3
    conn = sqlite3.connect(dblocation)

    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    data = pd.read_sql_query("SELECT CompanyName from CompanyData WHERE State='"+State+"'", conn)
    return data['CompanyName']
def get_soup(driver):
    html = driver.page_source
    soup = bs4.BeautifulSoup(html,'html.parser')
    return soup
def save_result(results,State):
    results = pd.DataFrame(results)[['CompanyName','regName','regNumber','RegDate', 'Jurisdiction','entType','status','address']]
    results.to_csv(State+'_results.csv',index=False)
    return results

# %% [markdown]
# ## Connect database

# %%
AL = load_data('AL')

# %%
AL
# Out:
# 0                                         ABC Coke
# 1                                        ADS Corp.
# 2                                   Advertiser Co.
# 3                   AEgis Technologies Group, Inc.
# 4                          AI Signal Research Inc.
# 5                                Alabama Gas Corp.
# 6                   Alabama Metal Industries Corp.
# 7                  Alabama River Pulp Company Inc.
# 8                                       Alfa Corp.
# 9                     Alto Products Corporation AL
# 10                              Am Pro Molding LLC
# 11                    American Color Graphics Inc.
# 12                         American Hardwoods Inc.
# 13                      American Marazzi Tile Inc.
# 14                     American Technologies, Inc.
# 15                              American Trim, LLC
# 16                                   Ampro Molding
# 17                     Andalusia Regional Hospital
# 18                  Anderson Electrical Connectors
# 19                       Anniston Sportswear Corp.
# 20                     Arkay Plastics Alabama Inc.
# 21                           Associated Pharmacies
# 22                       Athens Limestone Hospital
# 23                                             ATI
# 24                                     ATI Alldyne
# 25                       Atmore Community Hospital
# 26                         Atrion Medical Products
# 27                      Auburn Investment Castings
# 28                   Automatic Screw Machine Prods
# 29                      Azko Nobel Functional Chem
#                           ...
# 213                      Taratec Development Corp.
# 214                               Tecnoconsult S.A
# 215                TeleCommunication Systems, Inc.
# 216                Tensar Earth Technologies, Inc.
# 217                                Thermasys, Inc.
# 218                             Therma-Tron-X Inc.
# 219                                Therma-Tru Corp
# 220                              Thomason Hospital
# 221                         Tilsner Carton Company
# 222                     Tommy Hilfiger Corporation
# 223                                    TranS1, Inc
# 224                    Triangle Suspension Systems
# 225                          Tru Wall Concrete Inc
# 226                                         u-blox
# 227                   United States Postal Service
# 228    United Technologies Aerospace Systems (UTC)
# 229                Universal Health Services, Inc.
# 230                          University of Arizona
# 231                  Univision Communications Inc.
# 232                                US Tsubaki Inc.
# 233             USA SHADE & Fabric Structures, Inc
# 234                 Valley Regional Medical Center
# 235                                 ValueClick Inc
# 236                                    Vaupell Inc
# 237                         Venture Packaging Inc.
# 238                            Walker Products Inc
# 239                                   Weetabix Ltd
# 240                         WestCare Health System
# 241                  Womens Hospital of Greensboro
# 242                            WPS Resources Corp.
# Name: CompanyName, Length: 243, dtype: object

# %% [markdown]
# ## Search function

# %%
def ALbusiness(business):
    url = 'http://arc-sos.state.al.us/CGI/CORPNAME.MBR/INPUT'
    driver = webdriver.Chrome()
    driver.get(url)
 
    search = driver.find_element_by_xpath('//*[@id="block-sos-content"]/div/div/div[1]/form/div[1]/input')
    search.send_keys(business)
 
    submit = driver.find_element_by_xpath('//*[@id="block-sos-content"]/div/div/div[1]/form/div[6]/input')
    submit.click()
 

    time.sleep(1)
 
    if get_soup(driver)\
       .find(string = 'No matches found. ') != None:
        driver.quit()
        return [' ']*7
 
    driver\
    .find_element_by_xpath('//*[@id="block-sos-content"]/div/div/div/table/tbody/tr[1]/td[1]/a')\
    .click()
 
    time.sleep(3)
 
    soup = get_soup(driver)
    entType = soup.find("span",{"id":"MainContent_lblEntityType"}).text
    regNumber = soup.find("span",{"id":"MainContent_lblIDNumber"}).text
    regName = soup.find("span",{"id":"MainContent_lblEntityName"}).text
    status = ' '
    RegDate = soup.find("span",{"id":"MainContent_lblOrganisationDate"}).text
    try:
        Jurisdiction = soup.find("span",{"id":"MainContent_lblJurisdiction"}).text.split(":")[1].strip()
    except:
        Jurisdiction = ' '
    address = ' '
    driver.quit()
    return [regNumber, regName, RegDate, Jurisdiction, entType, status, address]

# %%
def F1(search,entity_name):
    try:
        search = search.lower().replace(',','').split()
        entity_name = entity_name.lower().replace(',','').split()               
        a = len([x for x in entity_name if x in search])
        b = len(entity_name)
        c = len(search)
        recall = a/b
        precision = a/c
        return 2*recall*precision/(recall + precision)
    except:
        return 0

# %%
def ALbusiness(business):
    driver = webdriver.Chrome()
    url = "http://arc-sos.state.al.us/CGI/CORPNAME.MBR/INPUT"
    driver.get(url)
    text = driver.find_element_by_name("search")
    text.send_keys(business)
    search_button = driver.find_element_by_xpath('//*[@id="block-sos-content"]/div/div/div[1]/form/div[6]/input')
    search_button.click()
    time.sleep(3)
    soup = get_soup(driver)
    company_info = list(map(lambda x: x.text, soup.find_all('td')[:-1]))
    company_list = []
    if len(company_info) < 5:
        driver.quit()
        print('No result')
        return [' ']*7
    company_list = []
    for i in range(len(company_info)//5):
        company_list.append({
        "Entity ID": company_info[i*5],
        "Entity Name": company_info[i*5+1]
        })
    company_list = pd.DataFrame(company_list)
    company_list['score'] = company_list['Entity Name'].apply(lambda x: F1(x,business))
    if max(company_list['score']) < 0.1:
        driver.quit()
        print('No result')
        return [' ']*7
    best_match = company_list.loc[company_list.score.idxmax(),'Entity Name']
    ## get details
    button = driver.find_element_by_xpath('//*[text()="'+best_match+'"]')
    button.click()
    time.sleep(3)
    soup_best = get_soup(driver)
    best_details = list(map(lambda x: x.text,soup_best.find_all('td')))
    best_details = list(map(lambda x: ' '.join(x.replace('\n','').replace('\xa0','').split()),best_details))[1:]
    idx1 = best_details.index('Capital Paid In')
    company_name  = best_details[:idx1]
    infodic = {'Principal Address':' ',
               'Entity Type':' ',
               'Principal Address':' ',
               'Formation Date':' ',
               'Status':' '
              }
    for i in range(len(company_name)//2):
        infodic[company_name[2*i]] = company_name[2*i + 1]
    address = infodic['Principal Address']
    Jurisdiction = ' '
    entType = infodic['Entity Type']
    regNumber = infodic['Entity ID Number']
    regName = best_match
    status = infodic['Status']
    RegDate = infodic['Formation Date']
    driver.quit()
    return [regNumber, regName, RegDate, Jurisdiction, entType, status, address]

# %% [markdown]
# ## Save Results

# %%
AL_results = []

# %%
for business in AL[len(AL_results):100]:
    searchResult = ALbusiness(business)
    AL_results.append({'CompanyName':business,'regNumber':searchResult[0], 'regName':searchResult[1],
                                    'RegDate':searchResult[2], 'Jurisdiction':searchResult[3],
                                     'entType':searchResult[4],
                                     'status': searchResult[5],'address':searchResult[6]})
# Out:
# No result
# No result
# No result
# No result
# No result
# No result
# No result
# No result
# No result
# No result
# No result
# No result

# %%
save_result(AL_results,'AL')
# Out:
#                              CompanyName  \
# 0                               ABC Coke
# 1                              ADS Corp.
# 2                         Advertiser Co.
# 3         AEgis Technologies Group, Inc.
# 4                AI Signal Research Inc.
# 5                      Alabama Gas Corp.
# 6         Alabama Metal Industries Corp.
# 7        Alabama River Pulp Company Inc.
# 8                             Alfa Corp.
# 9           Alto Products Corporation AL
# 10                    Am Pro Molding LLC
# 11          American Color Graphics Inc.
# 12               American Hardwoods Inc.
# 13            American Marazzi Tile Inc.
# 14           American Technologies, Inc.
# 15                    American Trim, LLC
# 16                         Ampro Molding
# 17           Andalusia Regional Hospital
# 18        Anderson Electrical Connectors
# 19             Anniston Sportswear Corp.
# 20           Arkay Plastics Alabama Inc.
# 21                 Associated Pharmacies
# 22             Athens Limestone Hospital
# 23                                   ATI
# 24                           ATI Alldyne
# 25             Atmore Community Hospital
# 26               Atrion Medical Products
# 27            Auburn Investment Castings
# 28         Automatic Screw Machine Prods
# 29            Azko Nobel Functional Chem
# ..                                   ...
# 70          Dentsply International, Inc.
# 71             DIXON TICONDEROGA COMPANY
# 72                Donalsonville Hospital
# 73             Donovan Data Systems Inc.
# 74                                   DPS
# 75                    Dry Creek Vineyard
# 76                     Duni Supply Corp.
# 77                   Dunkin' Brands, Inc
# 78                      DX Marketing LLC
# 79           East Carolina Neurology Inc
# 80              East Carolina University
# 81                      ECCO Corporation
# 82                   Era Helicopters LLC
# 83        Federal Reserve Bank of Boston
# 84                  Fieldale Farms Corp.
# 85                Filtrona Richmond Inc.
# 86      Financial Independence Group Inc
# 87                 Fleenor Paper Company
# 88                                Fortis
# 89                   Framatome ANP, Inc.
# 90                         Frame USA Inc
# 91           Franklin Precision Industry
# 92            G&J Pepsicola Bottling Co.
# 93  General Dynamics SATCOM Technologies
# 94                            Genta Inc.
# 95                          Globeleq Ltd
# 96                              GNU Inc.
# 97          Gold Standard Baking Company
# 98                    Golden State Foods
# 99              Golden State Foods Corp.
#
#                                           regName  regNumber     RegDate  \
# 14                             Domestic Corporation     Merged
# 15                Foreign Limited Liability Company     Exists
# 16               Domestic Limited Liability Company  Dissolved
# 17
# 18
# 19                             Domestic Corporation     Merged
# 20                             Domestic Corporation     Exists
# 21                             Domestic Corporation     Exists
# 22               Domestic Limited Liability Company     Exists
# 23                   Foreign Non-Profit Corporation     Exists
# 24
# 25
# 26                             Domestic Corporation  Dissolved
# 27
# 28
# 29
# ..          ...                                 ...        ...
# 70                              Foreign Corporation     Exists
# 71
# 72
# 73
# 74                             Domestic Corporation     Exists
# 75
# 76
# 77                              Foreign Corporation     Exists
# 78               Domestic Limited Liability Company     Exists
# 79
# 80
# 81                              Foreign Corporation  Withdrawn
# 82                Foreign Limited Liability Company     Exists
# 83
# 84
# 85
# 86                Foreign Limited Liability Company     Exists
# 87
# 88               Domestic Limited Liability Company     Exists
# 89                              Foreign Corporation     Exists
# 90
# 91
# 92
# 93
# 94                             Domestic Corporation     Exists
# 95
# 96                  Domestic Non-Profit Corporation     Exists
# 97
# 98                              Foreign Corporation     Exists
# 99                              Foreign Corporation     Exists
#
#                                               address
# 0                100 WEST TENTH STREET WILMINGTON, DE
# 1
# 2                                          MOBILE, AL
# 3                                      HUNTSVILLE, AL
# 4                                        Not Provided
# 5             100 W TENTH STREET WILMINGTON, DE 19801
# 6                                        DELAWARE, DE
# 7                                     MONROEVILLE, AL
# 8               100 WEST 10TH ST WILMINGTON, DE 19801
# 9
# 10                                     BIRMINGHAM, AL
# 11                 302 GROTE STREET BUFFALO, NY 14207
# 12                                        MADISON, AL
# 13         1301 YORK RD STE 800 LUTHERVILLE, MD 21093
# 14                                     MONTGOMERY, AL
# 15            1209 ORANGE STREET WILMINGTON, DE 19801
# 16                                     BIRMINGHAM, AL
# 17
# 18
# 19                                       ANNISTON, AL
# 20                                     MONTGOMERY, AL
# 21                                     SCOTTSBORO, AL
# 22                                       Not Provided
# 23           790 REMINGTON BLVD BOLINGBROOK, IL 60440
# 24
# 25
# 26                                           ARAB, AL
# 27
# 28
# 29
# ..                                                ...
# 70               221 W PHILADELPHIA ST YORK, PA 17404
# 71
# 72
# 73
# 74                                   JACKSONVILLE, AL
# 75
# 76
# 77                      130 ROYAL ST CANTON, MA 02021
# 78                                       Not Provided
# 79
# 80
# 81                  SCHUMAN ROAD MILLWOOD VILLAGE, NY
# 82      600 AIRPORT SERVICE RD LAKE CHARLES, LA 70607
# 83
# 84
# 85
# 86  19520 WEST CATAWBA AVE STE 200 CORNELIUS, NC 2...
# 87
# 88                                       Not Provided
# 89                 7207 IBM DRIVE CHARLOTTE, NC 28262
# 90
# 91
# 92
# 93
# 94                                     COLUMBIANA, AL
# 95
# 96                                       Not Provided
# 97
# 98  18301 VON KARMAN AVENUE STE 1100 IRVINE, CA 92...
# 99  18301 VON KARMAN AVENUE STE 1100 IRVINE, CA 92...
#
# [100 rows x 8 columns]
